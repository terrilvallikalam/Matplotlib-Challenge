# %% [markdown]
# ## Pymaceuticals

# %% [markdown]
# Summary:
# 1. Generally, the drug regimens were seen to help the mice's tumor volume over the study period.
# 2. Of the 10 different drug regimens, Capomulin was the most popular.
# 3. Based on the linear regression, there seems to be a positive correlation between weight and tumor volume.

# %%
# Dependencies and Setup
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "Resources/Mouse_metadata.csv"
study_results_path = "Resources/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
# Raw Data - mouse_metadata
mouse_metadata
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0       k403     Ramicane    Male          21          16
# 1       s185    Capomulin  Female           3          17
# 2       x401    Capomulin  Female          16          15
# 3       m601    Capomulin    Male          22          17
# 4       g791     Ramicane    Male          11          16
# ..       ...          ...     ...         ...         ...
# 244     z314     Stelasyn  Female          21          28
# 245     z435     Propriva  Female          12          26
# 246     z581    Infubinol  Female          24          25
# 247     z795     Naftisol  Female          13          29
# 248     z969     Naftisol    Male           9          30
#
# [249 rows x 5 columns]

# %%
# Raw Data - study_results
study_results
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        b128          0           45.000000                 0
# 1        f932          0           45.000000                 0
# 2        g107          0           45.000000                 0
# 3        a457          0           45.000000                 0
# 4        c819          0           45.000000                 0
# ...       ...        ...                 ...               ...
# 1888     r944         45           41.581521                 2
# 1889     u364         45           31.023923                 3
# 1890     p438         45           61.433892                 1
# 1891     x773         45           58.634971                 4
# 1892     b879         45           72.555239                 2
#
# [1893 rows x 4 columns]

# %%
# Combine the data into a single dataset and display the data table for preview
mice_data = pd.merge(mouse_metadata, study_results, how="left", on=["Mouse ID", "Mouse ID"])
mice_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
# Change Mouse ID to Mouse_ID
renamed_mice = mice_data.rename(columns={"Mouse ID":"Mouse_ID"})
renamed_mice
# Out:
#      Mouse_ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
# Checking the number of mice.
total_mice = renamed_mice.Mouse_ID.nunique()
total_mice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
final_mice = renamed_mice.drop_duplicates()
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
final_mice
# Out:
#      Mouse_ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1892 rows x 8 columns]

# %%
# Checking the number of mice in the clean DataFrame.
total_mice = final_mice.Mouse_ID.nunique()
total_mice
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# Mean, median, variance, standard deviation, and SEM of the tumor volume. 
grouped_drug = final_mice.groupby(['Drug Regimen'])
print(grouped_drug)
grouped_drug.count().head(10)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7fb265877b50>
#               Mouse_ID  Sex  Age_months  Weight (g)  Timepoint  \
# Drug Regimen
# Capomulin          230  230         230         230        230
# Ceftamin           178  178         178         178        178
# Infubinol          178  178         178         178        178
# Ketapril           188  188         188         188        188
# Naftisol           186  186         186         186        186
# Placebo            181  181         181         181        181
# Propriva           160  160         160         160        160
# Ramicane           228  228         228         228        228
# Stelasyn           181  181         181         181        181
# Zoniferol          182  182         182         182        182
#
#               Tumor Volume (mm3)  Metastatic Sites
# Drug Regimen
# Capomulin                    230               230
# Ceftamin                     178               178
# Infubinol                    178               178
# Ketapril                     188               188
# Naftisol                     186               186
# Placebo                      181               181
# Propriva                     160               160
# Ramicane                     228               228
# Stelasyn                     181               181
# Zoniferol                    182               182

# %%
# Mean
tumor_mean = grouped_drug['Tumor Volume (mm3)'].mean()
tumor_mean
# Out:
# Drug Regimen
# Capomulin    40.675741
# Ceftamin     52.591172
# Infubinol    52.884795
# Ketapril     55.235638
# Naftisol     54.331565
# Placebo      54.033581
# Propriva     52.368318
# Ramicane     40.216745
# Stelasyn     54.233149
# Zoniferol    53.236507
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Median
tumor_median = grouped_drug['Tumor Volume (mm3)'].median()
tumor_median
# Out:
# Drug Regimen
# Capomulin    41.557809
# Ceftamin     51.776157
# Infubinol    51.820584
# Ketapril     53.698743
# Naftisol     52.509285
# Placebo      52.288934
# Propriva     50.909965
# Ramicane     40.673236
# Stelasyn     52.431737
# Zoniferol    51.818479
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Variance
tumor_var = grouped_drug['Tumor Volume (mm3)'].var()
tumor_var
# Out:
# Drug Regimen
# Capomulin    24.947764
# Ceftamin     39.290177
# Infubinol    43.128684
# Ketapril     68.553577
# Naftisol     66.173479
# Placebo      61.168083
# Propriva     42.278090
# Ramicane     23.486704
# Stelasyn     59.450562
# Zoniferol    48.533355
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Standard Deviation
tumor_sd = grouped_drug['Tumor Volume (mm3)'].std()
tumor_sd
# Out:
# Drug Regimen
# Capomulin    4.994774
# Ceftamin     6.268188
# Infubinol    6.567243
# Ketapril     8.279709
# Naftisol     8.134708
# Placebo      7.821003
# Propriva     6.502160
# Ramicane     4.846308
# Stelasyn     7.710419
# Zoniferol    6.966589
# Name: Tumor Volume (mm3), dtype: float64

# %%
# SEM
tumor_sem = grouped_drug['Tumor Volume (mm3)'].sem()
tumor_sem
# Out:
# Drug Regimen
# Capomulin    0.329346
# Ceftamin     0.469821
# Infubinol    0.492236
# Ketapril     0.603860
# Naftisol     0.596466
# Placebo      0.581331
# Propriva     0.514041
# Ramicane     0.320955
# Stelasyn     0.573111
# Zoniferol    0.516398
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
summary_stats_df = pd.DataFrame({"Mean": tumor_mean,
                              "Median": tumor_median,
                               "Variance" : tumor_var,
                              "Standard Deviation": tumor_sd,
                              "SEM": tumor_sem})
summary_stats_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.368318  50.909965  42.278090            6.502160  0.514041
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Using the aggregation method, produce the same summary statistics in a single line
grouped_drug.agg({'Tumor Volume (mm3)': ["mean", "median", "var", "std", "sem"]})
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.368318  50.909965  42.278090  6.502160  0.514041
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Total number of measurements for each drug regimen
total_drugs = grouped_drug["Drug Regimen"].count()
total_drugs
# Out:
# Drug Regimen
# Capomulin    230
# Ceftamin     178
# Infubinol    178
# Ketapril     188
# Naftisol     186
# Placebo      181
# Propriva     160
# Ramicane     228
# Stelasyn     181
# Zoniferol    182
# Name: Drug Regimen, dtype: int64

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using Pandas.
total_drugs.plot(kind="bar")
measurements = [230, 178, 178, 188, 186, 181, 160, 228, 181, 182]
plt.ylim(0, max(measurements)+20)
plt.title("Total Measurements Taken per Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Total Measurements");

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using PyPlot.
Drug_Regimen = ["Capomulin", "Ceftamin", "Infubinol", "Ketapril", "Naftisol", "Placebo", "Propriva", "Ramicane", "Stelasyn", "Zoniferol"]
measurements = [230, 178, 178, 188, 186, 181, 160, 228, 181, 182]
x_axis = np.arange(len(measurements))
plt.bar(x_axis, measurements, color="g", align="center")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, Drug_Regimen, rotation="vertical")
plt.ylim(0, max(measurements)+20)
plt.title("Total Measurements Taken per Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Total Measurements");

# %%
# Total number of females and males in study
grouped_sex = final_mice.groupby(['Sex'])
total_sex = grouped_sex["Sex"].count()
total_sex
# Out:
# Sex
# Female    934
# Male      958
# Name: Sex, dtype: int64

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
total_sex.plot.pie(labels = ["Female", "Male"], colors = ["pink", "blue"], autopct="%1.2f%%")
# Out:
# <AxesSubplot:ylabel='Sex'>

# %%
# Generate a pie plot showing the distribution of female versus male mice using PyPlot
labels = ["Female", "Male"]
sizes = [934, 958]
colors = ["pink", "blue"]
plt.pie(sizes, labels=labels, colors=colors,
        autopct="%1.2f%%", startangle=0);

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Start by getting the last (greatest) timepoint for each mouse
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
drug = final_mice.set_index('Drug Regimen')
first = drug.drop(index=['Ketapril'])
second = first.drop(index=['Naftisol'])
third = second.drop(index=['Placebo'])
fourth = third.drop(index=['Propriva'])
fifth = fourth.drop(index=['Stelasyn'])
final_list = fifth.drop(index=['Zoniferol'])
final_list
# Out:
#              Mouse_ID     Sex  Age_months  Weight (g)  Timepoint  \
# Drug Regimen
# Ramicane         k403    Male          21          16          0
# Ramicane         k403    Male          21          16          5
# Ramicane         k403    Male          21          16         10
# Ramicane         k403    Male          21          16         15
# Ramicane         k403    Male          21          16         20
# ...               ...     ...         ...         ...        ...
# Infubinol        z581  Female          24          25         25
# Infubinol        z581  Female          24          25         30
# Infubinol        z581  Female          24          25         35
# Infubinol        z581  Female          24          25         40
# Infubinol        z581  Female          24          25         45
#
#               Tumor Volume (mm3)  Metastatic Sites
# Drug Regimen
# Ramicane               45.000000                 0
# Ramicane               38.825898                 0
# Ramicane               35.014271                 1
# Ramicane               34.223992                 1
# Ramicane               32.997729                 1
# ...                          ...               ...
# Infubinol              54.316407                 2
# Infubinol              56.286750                 2
# Infubinol              58.628399                 3
# Infubinol              60.053740                 3
# Infubinol              62.754451                 3
#
# [814 rows x 7 columns]

# %%
values = final_list.nlargest(63, 'Timepoint')
values
# Out:
#              Mouse_ID     Sex  Age_months  Weight (g)  Timepoint  \
# Drug Regimen
# Ramicane         k403    Male          21          16         45
# Capomulin        s185  Female           3          17         45
# Capomulin        x401  Female          16          15         45
# Capomulin        m601    Male          22          17         45
# Ramicane         g791    Male          11          16         45
# ...               ...     ...         ...         ...        ...
# Ceftamin         x822    Male           3          29         45
# Infubinol        y163  Female          17          27         45
# Ceftamin         y769  Female           6          27         45
# Ceftamin         y865    Male          23          26         45
# Infubinol        z581  Female          24          25         45
#
#               Tumor Volume (mm3)  Metastatic Sites
# Drug Regimen
# Ramicane               22.050126                 1
# Capomulin              23.343598                 1
# Capomulin              28.484033                 0
# Capomulin              28.430964                 1
# Ramicane               29.128472                 1
# ...                          ...               ...
# Ceftamin               61.386660                 3
# Infubinol              67.685569                 3
# Ceftamin               68.594745                 4
# Ceftamin               64.729837                 3
# Infubinol              62.754451                 3
#
# [63 rows x 7 columns]

# %%
timepoint = values['Timepoint']
timepoint
# Out:
# Drug Regimen
# Ramicane     45
# Capomulin    45
# Capomulin    45
# Capomulin    45
# Ramicane     45
#              ..
# Ceftamin     45
# Infubinol    45
# Ceftamin     45
# Ceftamin     45
# Infubinol    45
# Name: Timepoint, Length: 63, dtype: int64

# %%
tumor = values['Tumor Volume (mm3)']
tumor
# Out:
# Drug Regimen
# Ramicane     22.050126
# Capomulin    23.343598
# Capomulin    28.484033
# Capomulin    28.430964
# Ramicane     29.128472
#                ...
# Ceftamin     61.386660
# Infubinol    67.685569
# Ceftamin     68.594745
# Ceftamin     64.729837
# Infubinol    62.754451
# Name: Tumor Volume (mm3), Length: 63, dtype: float64

# %%
# Put treatments into a list for for loop (and later for plot labels)
# Create empty list to fill with tumor vol data (for plotting)
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
    # Locate the rows which contain mice on each drug and get the tumor volumes
    # add subset 
    # Determine outliers using upper and lower bounds
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
tumor_volume = values['Tumor Volume (mm3)']
fig1, ax1 = plt.subplots()
ax1.set_title('Tumor Volumes in Mice')
ax1.set_ylabel('Tumor Volume (mm3)')
ax1.boxplot(tumor_volume)
plt.show()

# %%
quartiles = tumor_volume.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq
print(f"The lower quartile of tumor volume is: {lowerq}")
print(f"The upper quartile of tumor volume is: {upperq}")
print(f"The interquartile range of tumor volmume is: {iqr}")
print(f"The the median of tumor volume is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.") #This produces a negative value which is not possible as a tumor volume. Thus, tumor volumes below 0 should be considered as outliers.
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of tumor volume is: 33.48002734
# The upper quartile of tumor volume is: 62.14221369
# The interquartile range of tumor volmume is: 28.66218635
# The the median of tumor volume is: 40.1592203
# Values below -9.513252184999999 could be outliers.
# Values above 105.135493215 could be outliers.

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
new_mice = final_mice.set_index('Mouse_ID')
capomulin_mouse = new_mice.loc['f966']
capomulin_mouse
# Out:
#          Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# Mouse_ID
# f966        Capomulin  Male          16          17          0
# f966        Capomulin  Male          16          17          5
# f966        Capomulin  Male          16          17         10
# f966        Capomulin  Male          16          17         15
# f966        Capomulin  Male          16          17         20
#
#           Tumor Volume (mm3)  Metastatic Sites
# Mouse_ID
# f966               45.000000                 0
# f966               38.796474                 0
# f966               35.624403                 0
# f966               32.623003                 0
# f966               30.485985                 0

# %%
x_axis = [0, 5, 10, 15, 20]
y_axis = [45.0, 38.796474, 35.624403, 32.623003, 30.485985]
plt.plot(x_axis, y_axis)
plt.xlim(0, 20)
plt.ylim(25, max(y_axis)+5)
plt.title("Mouse F966 Tumor Growth")
plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume (mm3)")
plt.grid()
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
grouped_mice = final_mice.groupby(['Drug Regimen','Mouse_ID']) 
average = grouped_mice.mean()
capomulin = average.head(25)
capomulin
# Out:
#                        Age_months  Weight (g)  Timepoint  Tumor Volume (mm3)  \
# Drug Regimen Mouse_ID
# Capomulin    b128             9.0        22.0       22.5           41.963636
#              b742             7.0        21.0       22.5           40.083699
#              f966            16.0        17.0       10.0           36.505973
#              g288             3.0        19.0       22.5           41.990097
#              g316            22.0        22.0       22.5           44.613344
#              i557             1.0        24.0       22.5           44.805810
#              i738            23.0        20.0       22.5           39.141053
#              j119             7.0        23.0       22.5           44.465236
#              j246            21.0        21.0       17.5           43.216925
#              l509            17.0        21.0       22.5           44.434474
#              l897            17.0        19.0       22.5           42.507261
#              m601            22.0        17.0       22.5           34.847470
#              m957             3.0        19.0       22.5           39.049816
#              r157            22.0        25.0        7.5           45.798970
#              r554             8.0        17.0       22.5           36.509212
#              r944            12.0        25.0       22.5           43.367364
#              s185             3.0        17.0       22.5           34.559143
#              s710             1.0        23.0       22.5           42.803733
#              t565            20.0        17.0       22.5           39.328725
#              u364            18.0        17.0       22.5           39.887495
#              v923            19.0        21.0       22.5           41.581595
#              w150            23.0        23.0        5.0           41.384825
#              w914            24.0        21.0       22.5           41.352452
#              x401            16.0        15.0       22.5           36.182040
#              y793            17.0        17.0       22.5           38.506829
#
#                        Metastatic Sites
# Drug Regimen Mouse_ID
# Capomulin    b128                  0.70
#              b742                  0.00
#              f966                  0.00
#              g288                  0.80
#              g316                  1.00
#              i557                  0.20
#              i738                  0.60
#              j119                  0.60
#              j246                  0.25
#              l509                  1.40
#              l897                  0.40
#              m601                  0.90
#              m957                  0.90
#              r157                  0.00
#              r554                  2.20
#              r944                  0.90
#              s185                  0.40
#              s710                  0.60
#              t565                  0.00
#              u364                  1.80
#              v923                  0.90
#              w150                  0.00
#              w914                  0.50
#              x401                  0.00
#              y793                  1.40

# %%
x_values = capomulin['Weight (g)']
y_values = capomulin['Tumor Volume (mm3)']
plt.scatter(x_values,y_values)
plt.scatter(x_values, y_values, marker="o", facecolors="green", edgecolors="black")
plt.title("Mouse Weight vs. Tumor Volume")
plt.xlabel("Weight (g)")
plt.ylabel("Tumor Volume (mm3)")
plt.show;

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient for mouse weight and average tumor volume for the Capomulin regimen
correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is 0.84

# %%
# Calculate the linear regression model for mouse weight and average tumor volume for the Capomulin regimen
x_values = capomulin['Weight (g)']
y_values = capomulin['Tumor Volume (mm3)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.scatter(x_values, y_values, marker="o", facecolors="green", edgecolors="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,36),fontsize=12,color="red")
plt.title("Mouse Weight vs. Tumor Volume")
plt.xlabel("Weight (g)")
plt.ylabel("Tumor Volume (mm3)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7088568047708717
